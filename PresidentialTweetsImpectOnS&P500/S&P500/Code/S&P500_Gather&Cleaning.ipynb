# %%
# Prerequisites
# pip install yfinance

# %%
import yfinance as yf

sp500 = yf.download("^GSPC", start="2010-01-01", end="2023-12-31")
print(sp500.head())

# %%
sp500_cleaned = sp500.dropna()
sp500_cleaned = sp500_cleaned[['Close']]
sp500_cleaned = sp500_cleaned.reset_index()
sp500_cleaned.to_csv('SP500_IndexCloses.csv', index=False)

# %%
import pandas as pd
import yfinance as yf

sp500_tickers = pd.read_csv('/Users/keremsmacbook/Desktop/gitHub/Presidential_Tweets_Impacts_SP500/PresidentialTweetsImpectOnS&P500/S&P500_Data/sp500_tickers.csv')

start_date = "2010-01-01"
end_date = "2023-12-31"

all_data = pd.DataFrame()
for ticker in sp500_tickers['0']:  
    data = yf.download(ticker, start=start_date, end=end_date)

    if 'Close' in data.columns:
        all_data[ticker] = data['Close']

all_data.to_csv('SP500_Closing_Prices.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
import pandas as pd
clo = pd.read_csv('SP500_Closing_Prices.csv')
clo.columns
# Out:
# Index(['Date', 'A', 'AAL', 'AAPL', 'ABBV', 'ABT', 'ACGL', 'ACN', 'ADBE', 'ADI',
#        ...
#        'WY', 'WYNN', 'XEL', 'XOM', 'XRAY', 'XYL', 'YUM', 'ZBH', 'ZBRA',
#        'ZION'],
#       dtype='object', length=461)
